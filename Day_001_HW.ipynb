# %% [markdown]
# ## 練習時間
# #### 請寫一個函式用來計算 Mean Square Error
# $ MSE = \frac{1}{n}\sum_{i=1}^{n}{(Y_i - \hat{Y}_i)^2} $
#
# ### Hint: [如何取平方](https://googoodesign.gitbooks.io/-ezpython/unit-1.html)

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
def mean_absolute_error(y, yp):
    """
    計算 MAE
    Args:
        - y: 實際值
        - yp: 預測值
    Return:
        - mae: MAE
    """
    mae = MAE = sum(abs(y - yp)) / len(y)
    return mae

MAE = mean_absolute_error(y, y_hat)
def mean_squared_error(y,yp):
    """
    請完成這個 Function 後往下執行
    """
    mse = MSE = sum(y - yp)**2 / len(y)
    return mse

MSE = mean_squared_error(y, y_hat)

# %%
w = 3
b = 0.5

x_lin = np.linspace(0, 100, 101)

y = (x_lin + np.random.randn(101) * 5) * w + b

plt.plot(x_lin, y, 'b.', label = 'data points')
plt.title("Assume we have data points")
plt.legend(loc = 2)
plt.show()

# %%
y_hat = x_lin * w + b
plt.plot(x_lin, y, 'b.', label = 'data')
plt.plot(x_lin, y_hat, 'r-', label = 'prediction')
plt.title("Assume we have data points (And the prediction)")
plt.legend(loc = 2)
plt.show()

# %%
# 執行 Function, 確認有沒有正常執行
MSE = mean_squared_error(y, y_hat)
MAE = mean_absolute_error(y, y_hat)
print("The Mean squared error is %.3f" % (MSE))
print("The Mean absolute error is %.3f" % (MAE))
# Out:
# The Mean squared error is 60.168
# The Mean absolute error is 10.499

# %%
作業1：

請上 Kaggle, 在 Competitions 或 Dataset 中找一組競賽或資料並寫下：

1. 你選的這組資料為何重要
我選擇的是"Suicide Rates Overview 1985 to 2016"，一個國家的自殺率有可能是不同因素所造成，透過這個長達32年的大型統計資料，
相信能夠透過反覆運算，找出造成自殺率高的前幾大因素，以協助政府在檢視國家經濟狀況等條件時，能提早預警改良政策的執行，減少自殺的發生。

2. 資料從何而來 (tips: 譬如提供者是誰、以什麼方式蒐集)
這個資料是從Kaggle的dataset找到的，資料集的來源是整合了四個統計資料，包括：
United Nations Development Program. (2018). 
World Bank. (2018). 
[Szamil]. (2017). Suicide in the Twenty-First Century [dataset]. 
World Health Organization. (2018). Suicide prevention. 
是世界的統計資料。

3. 蒐集而來的資料型態為何
資料型態為csv檔，容量2.58MB, 裡面有12個columns,分別為country, year, sex, age group, count of suicides, population, suicide rate, country-year composite key, HDI for year, gdp_for_year, gdp_per_capita, generation (based on age grouping average).

4. 這組資料想解決的問題如何評估
以社會經濟因素為主要評估因素，結合年齡、性別等，找出最為影響自殺發生的因素為何，達到能預測自殺的目的。

# %%
作業2：

想像你經營一個自由載客車隊，你希望能透過數據分析以提升業績，請你思考並描述你如何規劃整體的分析/解決方案：

1. 核心問題為何 (tips：如何定義 「提升業績 & 你的假設」)
在什麼地段、什麼時間點、什麼客群、客群的目的地，能讓我們以最不費力不費時的方式載客量也同時提升？
假設：在台北市辦公大樓聚集地段，上下班時間能提升載客率。

2. 資料從何而來 (tips：哪些資料可能會對你想問的問題產生影響 & 資料如何蒐集)
整個台北市的車流量分佈，可以不同區區分，平均紅綠燈秒數，平均腳踏車租借情形，平均公車間隔分鐘數及載客量，這些資料可由交通局查詢是否有相關公開資料，另外，過去我們車隊在這些路段
不同時間的載客情形等相關資料也都能成為考慮的因素。

3. 蒐集而來的資料型態為何
需整理為csv檔，至少要有完整一年資料，可以的話以每小時為單位，有每個小時的資料為佳。

4. 你要回答的問題，其如何評估 (tips：你的假設如何驗證)
由這些所有的因素當中，反覆運算出，是否在台北市辦公大樓地段，上下班時間能提升載客率。
